# %%
import sys
import importlib

sys.path.append(r"D:\GENAI\Agentic AI Projects\AgenticTrip\backend")

import app.tools.places_tool as places_tool

importlib.reload(places_tool)
# Out:
# <module 'app.tools.places_tool' from 'D:\\GENAI\\Agentic AI Projects\\AgenticTrip\\backend\\app\\tools\\places_tool.py'>

# %%
from app.tools.places_tool import search_places

places_tool.search_places(
    "Seminyak Bali",
    "night clubs"
)
# Out:
# [{'name': 'ShiShi Nightclub & Izakaya Lounge',
#   'address': 'Jl. Petitenget No.208X, Kerobokan Kelod, Kec. Kuta Utara, Kabupaten Badung, Bali 80361, Indonesia',
#   'rating': 4.7},
#  {'name': 'La Favela',
#   'address': 'Jl. Laksamana Basangkasa No.177X, Seminyak, Kec. Kuta, Kabupaten Badung, Bali 80361, Indonesia',
#   'rating': 4.4},
#  {'name': 'Motel Mexicola',
#   'address': 'Jl. Kayu Jati No.9X, Kerobokan Kelod, Kec. Kuta Utara, Kabupaten Badung, Bali 80361, Indonesia',
#   'rating': 4.5},
#  {'name': 'The Iron Fairies Bali',
#   'address': 'Jl. Petitenget No.19x, Kerobokan Kelod, Kec. Kuta Utara, Kabupaten Badung, Bali 80361, Indonesia',
#   'rating': 4.8},
#  {'name': 'Red Ruby Bali',
#   'address': 'Seminyak No.919, Jl. Petitenget, Kerobokan Kelod, Kuta Utara, Badung Regency, Bali 80361, Indonesia',
#   'rating': 3.9}]
